# %% [markdown]
# ## Audiobooks Example Preprocessing

# %% [markdown]
# ## Import relevant libraries

# %%
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import statsmodels.api
import seaborn as sns
import pandas as pd
sns.set()

# %% [markdown]
# ## Extract data from csv

# %%
raw_data = pd.read_csv('Test.csv')
raw_data
# Out:
#       country  year       uniqueid location_type cellphone_access  \
# 0       Kenya  2018  uniqueid_6056         Urban              Yes
# 1       Kenya  2018  uniqueid_6060         Urban              Yes
# 2       Kenya  2018  uniqueid_6065         Rural               No
# 3       Kenya  2018  uniqueid_6072         Rural               No
# 4       Kenya  2018  uniqueid_6073         Urban               No
# 5       Kenya  2018  uniqueid_6074         Rural              Yes
# 6       Kenya  2018  uniqueid_6075         Rural              Yes
# 7       Kenya  2018  uniqueid_6076         Urban              Yes
# 8       Kenya  2018  uniqueid_6077         Rural              Yes
# 9       Kenya  2018  uniqueid_6078         Urban              Yes
# 10      Kenya  2018  uniqueid_6079         Rural               No
# 11      Kenya  2018  uniqueid_6080         Rural               No
# 12      Kenya  2018  uniqueid_6081         Rural               No
# 13      Kenya  2018  uniqueid_6082         Urban              Yes
# 14      Kenya  2018  uniqueid_6083         Urban              Yes
# 15      Kenya  2018  uniqueid_6084         Rural              Yes
# 16      Kenya  2018  uniqueid_6085         Rural              Yes
# 17      Kenya  2018  uniqueid_6086         Rural               No
# 18      Kenya  2018  uniqueid_6087         Urban               No
# 19      Kenya  2018  uniqueid_6088         Urban               No
# 20      Kenya  2018  uniqueid_6089         Rural              Yes
# 21      Kenya  2018  uniqueid_6090         Rural               No
# 22      Kenya  2018  uniqueid_6091         Rural              Yes
# 23      Kenya  2018  uniqueid_6092         Urban              Yes
# 24      Kenya  2018  uniqueid_6093         Rural              Yes
# 25      Kenya  2018  uniqueid_6094         Urban               No
# 26      Kenya  2018  uniqueid_6095         Rural               No
# 27      Kenya  2018  uniqueid_6096         Rural              Yes
# 28      Kenya  2018  uniqueid_6097         Rural              Yes
# 29      Kenya  2018  uniqueid_6098         Urban              Yes
# ...       ...   ...            ...           ...              ...
# 10056  Uganda  2018  uniqueid_2973         Urban              Yes
# 10057  Uganda  2018  uniqueid_2974         Rural              Yes
# 10058  Uganda  2018  uniqueid_2975         Rural              Yes
# 10059  Uganda  2018  uniqueid_2976         Rural               No
# 10060  Uganda  2018  uniqueid_2977         Urban              Yes
# 10061  Uganda  2018  uniqueid_2978         Urban               No
# 10062  Uganda  2018  uniqueid_2979         Rural              Yes
# 10063  Uganda  2018  uniqueid_2980         Rural               No
# 10064  Uganda  2018  uniqueid_2981         Rural               No
# 10065  Uganda  2018  uniqueid_2982         Urban              Yes
# 10066  Uganda  2018  uniqueid_2983         Rural              Yes
# 10067  Uganda  2018  uniqueid_2984         Urban              Yes
# 10068  Uganda  2018  uniqueid_2985         Rural               No
# 10069  Uganda  2018  uniqueid_2986         Rural              Yes
# 10070  Uganda  2018  uniqueid_2987         Urban              Yes
# 10071  Uganda  2018  uniqueid_2988         Rural              Yes
# 10072  Uganda  2018  uniqueid_2989         Rural               No
# 10073  Uganda  2018  uniqueid_2990         Rural              Yes
# 10074  Uganda  2018  uniqueid_2991         Rural              Yes
# 10075  Uganda  2018  uniqueid_2992         Rural               No
# 10076  Uganda  2018  uniqueid_2993         Rural              Yes
# 10077  Uganda  2018  uniqueid_2994         Rural              Yes
# 10078  Uganda  2018  uniqueid_2995         Rural               No
# 10079  Uganda  2018  uniqueid_2996         Urban              Yes
# 10080  Uganda  2018  uniqueid_2997         Rural              Yes
# 10081  Uganda  2018  uniqueid_2998         Rural               No
# 10082  Uganda  2018  uniqueid_2999         Urban              Yes
# 10083  Uganda  2018  uniqueid_3000         Urban              Yes
# 10084  Uganda  2018  uniqueid_3001         Rural              Yes
# 10085  Uganda  2018  uniqueid_3002         Urban              Yes
#
#        household_size  age_of_respondent gender_of_respondent  \
# 0                   3                 30                 Male
# 1                   7                 51                 Male
# 2                   3                 77               Female
# 3                   6                 39               Female
# 4                   3                 16                 Male
# 5                   4                 25               Female
# 6                   4                 32               Female
# 7                   3                 24               Female
# 8                   4                 22               Female
# 9                   1                 42                 Male
# 10                  5                 18                 Male
# 11                  3                 20                 Male
# 12                  7                 32               Female
# 13                  6                 19               Female
# 14                  2                 26               Female
# 15                  4                 18                 Male
# 16                  5                 35                 Male
# 17                  1                 68               Female
# 18                  5                 20               Female
# 19                  7                 70                 Male
# 20                  4                 34               Female
# 21                  1                 95               Female
# 22                  1                 30               Female
# 23                  4                 27                 Male
# 24                  1                 70               Female
# 25                  9                 21               Female
# 26                  4                 45                 Male
# 27                  6                 52               Female
# 28                  1                 44               Female
# 29                  4                 21               Female
# ...               ...                ...                  ...
# 10056               7                 31               Female
# 10057              10                 18                 Male
# 10058               7                 42                 Male
# 10059               6                 50                 Male
# 10060               8                 19               Female
# 10061               2                 49               Female
# 10062               2                 32                 Male
# 10063               4                 47               Female
# 10064               7                 40               Female
# 10065               2                 23                 Male
# 10066               7                 32               Female
# 10067              10                 32               Female
# 10068              12                 20                 Male
# 10069               7                 37               Female
# 10070               5                 18               Female
# 10071               3                 38               Female
# 10072               2                 65               Female
# 10073               3                 59               Female
# 10074               2                 34               Female
# 10075               4                 27               Female
# 10076               5                 46                 Male
# 10077               6                 30               Female
# 10078               8                 30               Female
# 10079               9                 37               Female
# 10080               2                 22                 Male
# 10081               2                 62               Female
# 10082               8                 42                 Male
# 10083               1                 39                 Male
# 10084               6                 28               Female
# 10085               7                 16                 Male
#
#       relationship_with_head           marital_status  \
# 0          Head of Household  Married/Living together
# 1          Head of Household  Married/Living together
# 2                     Parent  Married/Living together
# 3          Head of Household  Married/Living together
# 4                      Child     Single/Never Married
# 5                     Spouse  Married/Living together
# 6          Head of Household       Divorced/Seperated
# 7                     Spouse  Married/Living together
# 8                      Child     Single/Never Married
# 9          Head of Household       Divorced/Seperated
# 10                     Child     Single/Never Married
# 11            Other relative  Married/Living together
# 12                    Spouse  Married/Living together
# 13                     Child  Married/Living together
# 14                     Child     Single/Never Married
# 15                     Child     Single/Never Married
# 16         Head of Household  Married/Living together
# 17         Head of Household       Divorced/Seperated
# 18                     Child     Single/Never Married
# 19         Head of Household  Married/Living together
# 20                    Spouse  Married/Living together
# 21         Head of Household                  Widowed
# 22         Head of Household     Single/Never Married
# 23         Head of Household  Married/Living together
# 24         Head of Household                  Widowed
# 25                     Child     Single/Never Married
# 26         Head of Household  Married/Living together
# 27         Head of Household     Single/Never Married
# 28         Head of Household       Divorced/Seperated
# 29                     Child     Single/Never Married
# ...                      ...                      ...
# 10056                 Spouse  Married/Living together
# 10057                  Child     Single/Never Married
# 10058      Head of Household  Married/Living together
# 10059      Head of Household  Married/Living together
# 10060                 Parent     Single/Never Married
# 10061      Head of Household                  Widowed
# 10062      Head of Household  Married/Living together
# 10063      Head of Household  Married/Living together
# 10064      Head of Household  Married/Living together
# 10065      Head of Household     Single/Never Married
# 10066                 Spouse  Married/Living together
# 10067                 Spouse  Married/Living together
# 10068      Head of Household  Married/Living together
# 10069                 Spouse  Married/Living together
# 10070                 Parent     Single/Never Married
# 10071      Head of Household  Married/Living together
# 10072      Head of Household  Married/Living together
# 10073      Head of Household                  Widowed
# 10074                 Spouse  Married/Living together
# 10075                 Spouse  Married/Living together
# 10076      Head of Household  Married/Living together
# 10077                 Spouse  Married/Living together
# 10078                 Spouse  Married/Living together
# 10079                 Spouse  Married/Living together
# 10080    Other non-relatives     Single/Never Married
# 10081                 Spouse  Married/Living together
# 10082      Head of Household  Married/Living together
# 10083      Head of Household     Single/Never Married
# 10084                 Spouse  Married/Living together
# 10085         Other relative     Single/Never Married
#
#                        education_level                      job_type
# 0                  Secondary education  Formally employed Government
# 1      Vocational/Specialised training     Formally employed Private
# 2                  No formal education          Remittance Dependent
# 3                    Primary education          Remittance Dependent
# 4                  Secondary education          Remittance Dependent
# 5                    Primary education                 Self employed
# 6                    Primary education           Informally employed
# 7      Vocational/Specialised training                 Self employed
# 8                    Primary education           Informally employed
# 9                  Secondary education           Farming and Fishing
# 10                   Primary education          Remittance Dependent
# 11                   Primary education           Informally employed
# 12                   Primary education           Informally employed
# 13                   Primary education           Informally employed
# 14                 Secondary education          Remittance Dependent
# 15                 Secondary education          Remittance Dependent
# 16     Vocational/Specialised training     Formally employed Private
# 17                   Primary education           Farming and Fishing
# 18                 Secondary education          Remittance Dependent
# 19                 No formal education          Government Dependent
# 20                   Primary education           Farming and Fishing
# 21                   Primary education          Government Dependent
# 22                   Primary education          Remittance Dependent
# 23                 Secondary education           Informally employed
# 24                   Primary education           Farming and Fishing
# 25                 Secondary education          Remittance Dependent
# 26                   Primary education                 Self employed
# 27                 Secondary education           Farming and Fishing
# 28                 Secondary education           Informally employed
# 29                 Secondary education          Remittance Dependent
# ...                                ...                           ...
# 10056                Primary education                  Other Income
# 10057                Primary education                 Self employed
# 10058                Primary education                 Self employed
# 10059              Secondary education                 Self employed
# 10060              Secondary education                  Other Income
# 10061                Primary education                 Self employed
# 10062              Secondary education                 Self employed
# 10063              No formal education                 Self employed
# 10064              No formal education                 Self employed
# 10065              Secondary education                 Self employed
# 10066                Primary education                  Other Income
# 10067              Secondary education                 Self employed
# 10068                Primary education                 Self employed
# 10069              Secondary education                 Self employed
# 10070              Secondary education                     No Income
# 10071  Vocational/Specialised training     Formally employed Private
# 10072              No formal education                 Self employed
# 10073                Primary education                 Self employed
# 10074                Primary education                 Self employed
# 10075                Primary education                  Other Income
# 10076                Primary education                 Self employed
# 10077                Primary education                 Self employed
# 10078                Primary education                 Self employed
# 10079              Secondary education                  Other Income
# 10080              Secondary education                 Self employed
# 10081                Primary education                 Self employed
# 10082                Primary education                 Self employed
# 10083              Secondary education                  Other Income
# 10084                Primary education                 Self employed
# 10085              Secondary education                  Other Income
#
# [10086 rows x 12 columns]

# %% [markdown]
# ## Preprocessing

# %%
raw_data.describe(include='all')
# Out:
#        country          year       uniqueid location_type cellphone_access  \
# count    10086  10086.000000          10086         10086            10086
# unique       4           NaN           7313             2                2
# top     Rwanda           NaN  uniqueid_8535         Rural              Yes
# freq      3745           NaN              3          6189             7559
# mean       NaN   2016.975907            NaN           NaN              NaN
# std        NaN      0.847356            NaN           NaN              NaN
# min        NaN   2016.000000            NaN           NaN              NaN
# 25%        NaN   2016.000000            NaN           NaN              NaN
# 50%        NaN   2017.000000            NaN           NaN              NaN
# 75%        NaN   2018.000000            NaN           NaN              NaN
# max        NaN   2018.000000            NaN           NaN              NaN
#
#         household_size  age_of_respondent gender_of_respondent  \
# count     10086.000000       10086.000000                10086
# unique             NaN                NaN                    2
# top                NaN                NaN               Female
# freq               NaN                NaN                 5847
# mean          3.778802          38.308348                  NaN
# std           2.212721          16.270053                  NaN
# min           1.000000          16.000000                  NaN
# 25%           2.000000          26.000000                  NaN
# 50%           3.000000          35.000000                  NaN
# 75%           5.000000          48.000000                  NaN
# max          20.000000         100.000000                  NaN
#
#        relationship_with_head           marital_status    education_level  \
# count                   10086                    10086              10086
# unique                      6                        5                  6
# top         Head of Household  Married/Living together  Primary education
# freq                     5487                     4663               5479
# mean                      NaN                      NaN                NaN
# std                       NaN                      NaN                NaN
# min                       NaN                      NaN                NaN
# 25%                       NaN                      NaN                NaN
# 50%                       NaN                      NaN                NaN
# 75%                       NaN                      NaN                NaN
# max                       NaN                      NaN                NaN
#
#              job_type
# count           10086
# unique             10
# top     Self employed
# freq             2773
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %% [markdown]
# ## Determining the variables of interest

# %%
data = raw_data.drop(['uniqueid','year'],axis=1)
data.describe(include='all')
# Out:
#        country location_type cellphone_access  household_size  \
# count    10086         10086            10086    10086.000000
# unique       4             2                2             NaN
# top     Rwanda         Rural              Yes             NaN
# freq      3745          6189             7559             NaN
# mean       NaN           NaN              NaN        3.778802
# std        NaN           NaN              NaN        2.212721
# min        NaN           NaN              NaN        1.000000
# 25%        NaN           NaN              NaN        2.000000
# 50%        NaN           NaN              NaN        3.000000
# 75%        NaN           NaN              NaN        5.000000
# max        NaN           NaN              NaN       20.000000
#
#         age_of_respondent gender_of_respondent relationship_with_head  \
# count        10086.000000                10086                  10086
# unique                NaN                    2                      6
# top                   NaN               Female      Head of Household
# freq                  NaN                 5847                   5487
# mean            38.308348                  NaN                    NaN
# std             16.270053                  NaN                    NaN
# min             16.000000                  NaN                    NaN
# 25%             26.000000                  NaN                    NaN
# 50%             35.000000                  NaN                    NaN
# 75%             48.000000                  NaN                    NaN
# max            100.000000                  NaN                    NaN
#
#                  marital_status    education_level       job_type
# count                     10086              10086          10086
# unique                        5                  6             10
# top     Married/Living together  Primary education  Self employed
# freq                       4663               5479           2773
# mean                        NaN                NaN            NaN
# std                         NaN                NaN            NaN
# min                         NaN                NaN            NaN
# 25%                         NaN                NaN            NaN
# 50%                         NaN                NaN            NaN
# 75%                         NaN                NaN            NaN
# max                         NaN                NaN            NaN

# %% [markdown]
# ## Dealing with missing values

# %%
data.isnull().sum()
# Out:
# country                   0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %% [markdown]
# ## Dealing with categorical values

# %%
data['gender_of_respondent'] = data['gender_of_respondent'].map({'Male':1,'Female':0})
data['cellphone_access'] = data['cellphone_access'].map({'Yes':1,'No':0})

# %%
data.describe(include='all')
# Out:
#        country location_type  cellphone_access  household_size  \
# count    10086         10086      10086.000000    10086.000000
# unique       4             2               NaN             NaN
# top     Rwanda         Rural               NaN             NaN
# freq      3745          6189               NaN             NaN
# mean       NaN           NaN          0.749455        3.778802
# std        NaN           NaN          0.433349        2.212721
# min        NaN           NaN          0.000000        1.000000
# 25%        NaN           NaN          0.000000        2.000000
# 50%        NaN           NaN          1.000000        3.000000
# 75%        NaN           NaN          1.000000        5.000000
# max        NaN           NaN          1.000000       20.000000
#
#         age_of_respondent  gender_of_respondent relationship_with_head  \
# count        10086.000000          10086.000000                  10086
# unique                NaN                   NaN                      6
# top                   NaN                   NaN      Head of Household
# freq                  NaN                   NaN                   5487
# mean            38.308348              0.420286                    NaN
# std             16.270053              0.493629                    NaN
# min             16.000000              0.000000                    NaN
# 25%             26.000000              0.000000                    NaN
# 50%             35.000000              0.000000                    NaN
# 75%             48.000000              1.000000                    NaN
# max            100.000000              1.000000                    NaN
#
#                  marital_status    education_level       job_type
# count                     10086              10086          10086
# unique                        5                  6             10
# top     Married/Living together  Primary education  Self employed
# freq                       4663               5479           2773
# mean                        NaN                NaN            NaN
# std                         NaN                NaN            NaN
# min                         NaN                NaN            NaN
# 25%                         NaN                NaN            NaN
# 50%                         NaN                NaN            NaN
# 75%                         NaN                NaN            NaN
# max                         NaN                NaN            NaN

# %%
data_with_dummies = pd.get_dummies(data,drop_first=True)
data_with_dummies.describe()
# Out:
#        cellphone_access  household_size  age_of_respondent  \
# count      10086.000000    10086.000000       10086.000000
# mean           0.749455        3.778802          38.308348
# std            0.433349        2.212721          16.270053
# min            0.000000        1.000000          16.000000
# 25%            0.000000        2.000000          26.000000
# 50%            1.000000        3.000000          35.000000
# 75%            1.000000        5.000000          48.000000
# max            1.000000       20.000000         100.000000
#
#        gender_of_respondent  country_Rwanda  country_Tanzania  country_Uganda  \
# count          10086.000000    10086.000000      10086.000000    10086.000000
# mean               0.420286        0.371307          0.281479        0.089332
# std                0.493629        0.483178          0.449743        0.285236
# min                0.000000        0.000000          0.000000        0.000000
# 25%                0.000000        0.000000          0.000000        0.000000
# 50%                0.000000        0.000000          0.000000        0.000000
# 75%                1.000000        1.000000          1.000000        0.000000
# max                1.000000        1.000000          1.000000        1.000000
#
#        location_type_Urban  relationship_with_head_Head of Household  \
# count         10086.000000                              10086.000000
# mean              0.386377                                  0.544021
# std               0.486943                                  0.498083
# min               0.000000                                  0.000000
# 25%               0.000000                                  0.000000
# 50%               0.000000                                  1.000000
# 75%               1.000000                                  1.000000
# max               1.000000                                  1.000000
#
#        relationship_with_head_Other non-relatives  ...  \
# count                                10086.000000  ...
# mean                                     0.006841  ...
# std                                      0.082432  ...
# min                                      0.000000  ...
# 25%                                      0.000000  ...
# 50%                                      0.000000  ...
# 75%                                      0.000000  ...
# max                                      1.000000  ...
#
#        education_level_Vocational/Specialised training  \
# count                                     10086.000000
# mean                                          0.035594
# std                                           0.185285
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        job_type_Farming and Fishing  job_type_Formally employed Government  \
# count                  10086.000000                           10086.000000
# mean                       0.234979                               0.016458
# std                        0.424007                               0.127237
# min                        0.000000                               0.000000
# 25%                        0.000000                               0.000000
# 50%                        0.000000                               0.000000
# 75%                        0.000000                               0.000000
# max                        1.000000                               1.000000
#
#        job_type_Formally employed Private  job_type_Government Dependent  \
# count                        10086.000000                   10086.000000
# mean                             0.044021                       0.009915
# std                              0.205153                       0.099083
# min                              0.000000                       0.000000
# 25%                              0.000000                       0.000000
# 50%                              0.000000                       0.000000
# 75%                              0.000000                       0.000000
# max                              1.000000                       1.000000
#
#        job_type_Informally employed  job_type_No Income  \
# count                  10086.000000        10086.000000
# mean                       0.235177            0.027365
# std                        0.424131            0.163152
# min                        0.000000            0.000000
# 25%                        0.000000            0.000000
# 50%                        0.000000            0.000000
# 75%                        0.000000            0.000000
# max                        1.000000            1.000000
#
#        job_type_Other Income  job_type_Remittance Dependent  \
# count           10086.000000                   10086.000000
# mean                0.041939                       0.109756
# std                 0.200460                       0.312601
# min                 0.000000                       0.000000
# 25%                 0.000000                       0.000000
# 50%                 0.000000                       0.000000
# 75%                 0.000000                       0.000000
# max                 1.000000                       1.000000
#
#        job_type_Self employed
# count            10086.000000
# mean                 0.274936
# std                  0.446504
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  1.000000
# max                  1.000000
#
# [8 rows x 31 columns]

# %%
unscaled_inputs_all = data_with_dummies.copy()

# %%
unscaled_inputs_all.shape
# Out:
# (10086, 31)

# %% [markdown]
# ## Standardize the inputs

# %%
scaled_inputs = preprocessing.scale(unscaled_inputs_all)

# %% [markdown]
# ## Save the three datasets in *.npz

# %%
np.savez('AI_HACK_data_hack_test',inputs=scaled_inputs)

# %%
data_formated = raw_data.copy()

# %%
data_formated.head()
# Out:
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# 3                 39               Female      Head of Household
# 4                 16                 Male                  Child
#
#             marital_status                  education_level  \
# 0  Married/Living together              Secondary education
# 1  Married/Living together  Vocational/Specialised training
# 2  Married/Living together              No formal education
# 3  Married/Living together                Primary education
# 4     Single/Never Married              Secondary education
#
#                        job_type
# 0  Formally employed Government
# 1     Formally employed Private
# 2          Remittance Dependent
# 3          Remittance Dependent
# 4          Remittance Dependent

# %%
data_formated['uniqueid'] = data_formated['uniqueid'] +' x '+data_formated['country']

# %%
data_formated.head()
# Out:
#   country  year               uniqueid location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_6056 x Kenya         Urban              Yes
# 1   Kenya  2018  uniqueid_6060 x Kenya         Urban              Yes
# 2   Kenya  2018  uniqueid_6065 x Kenya         Rural               No
# 3   Kenya  2018  uniqueid_6072 x Kenya         Rural               No
# 4   Kenya  2018  uniqueid_6073 x Kenya         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 30                 Male
# 1               7                 51                 Male
# 2               3                 77               Female
# 3               6                 39               Female
# 4               3                 16                 Male
#
#   relationship_with_head           marital_status  \
# 0      Head of Household  Married/Living together
# 1      Head of Household  Married/Living together
# 2                 Parent  Married/Living together
# 3      Head of Household  Married/Living together
# 4                  Child     Single/Never Married
#
#                    education_level                      job_type
# 0              Secondary education  Formally employed Government
# 1  Vocational/Specialised training     Formally employed Private
# 2              No formal education          Remittance Dependent
# 3                Primary education          Remittance Dependent
# 4              Secondary education          Remittance Dependent

# %%
np.savez('AI_HACK_data_hack_test_uniquid',uniquid=data_formated['uniqueid'])
